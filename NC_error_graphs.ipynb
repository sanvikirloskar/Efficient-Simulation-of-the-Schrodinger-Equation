# %%
#Making plots for errors
import matplotlib.pyplot as plt
import numpy as np
xlabels = ["1D", "2D"]
ylabels = ["Error in Max Expectation Value"]
newt_errors = [4.712, 0.213]
cheb_errors = [4.712, 0.213]
x = np.arange(len(xlabels))
width = 0.35
fig, ax = plt.subplots(figsize=(8,6))

bars1 = ax.bar(x - width/2, newt_errors, width, label='Newtonian', color='C0')
bars2 = ax.bar(x + width/2, cheb_errors, width, label='Semi-Global', color='C1')

ax.set_xlabel('Simulation Type')
ax.set_ylabel('Error in Max Expectation Value')
ax.set_title('Error Comparison Between 1D and 2D Simulations')
ax.set_xticks(x)
ax.set_xticklabels(xlabels)
ax.legend()
plt.show()
